# %%
import os
files = os.listdir('../pubmed/PICO-data/docs/')

# %%
del files[files.index('mesh_tags')]

# %%
import pandas as pd

# %%
texts = [open('../pubmed/PICO-data/docs/' + name).read() for name in files]

# %%
ids = [name[:-4] for name in files]

# %%
df = pd.DataFrame({'text' : texts, 'idx' : ids})

# %%
df
# Out:
#            idx                                               text
# 0     21664757  Positive impact of crisis resource management ...
# 1     21047593  Lead-time in the European Randomised Study of ...
# 2     10195003  A comparison of a non-ionic dimer, iodixanol w...
# 3     17872451  Nateglinide reduces carotid intima-media thick...
# 4       526820  A tube spacer to improve inhalation of drugs f...
# 5      8198938  Trimetazidine: a new concept in the treatment ...
# 6     19407805  Ambulatory blood pressure control with bedtime...
# 7      1289508  Left ventricular mass regression in elderly hy...
# 8     19708471  Qigong massage treatment for sensory and self-...
# 9     24097277  The efficacy and safety of simultaneous transu...
# 10    23995030  Incremental cost-effectiveness of pharmacother...
# 11    21669557  Intervention to lower household wood smoke exp...
# 12    10337657  Effect of total androgen ablation on pathologi...
# ...
