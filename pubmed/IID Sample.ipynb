# %%
import pandas as pd

# %%
df = pd.read_csv('pubmed_data_dedup_n.csv')

# %%
labels = df['label'].unique()

# %%
df_arthro = df[df['label'] == labels[0]]

# %%
df_arthro
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1       idx  \
# 0              0             0               0  24459172
# 1              1             1               1  16430668
# 2              2             2               2  11817871
# 3              3             3               3  18835692
# 4              4             4               4  22682044
# 5              5             5               5   9669008
# 6              6             6               6  21786544
# 7              7             7               7  26130344
# 8              8             8               8  26130342
# 9              9             9               9  26130341
# 10            10            10              10  10776741
# 11            11            11              11  17534206
# 12            12            12              12  12657073
# 13            13            13              13  18580181
# 14            14            14              14  25410510
# ...

# %%
df_a_50 = df_arthro.sample(n=50)

# %%
df_a_50 = df_a_50.reset_index().drop(['index', 'Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1'], axis=1)

# %%
df_a_50.to_csv('Arthro_50_pubmed.csv', index=False)
